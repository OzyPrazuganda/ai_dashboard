# %%
import gspread
import pandas as pd
from google.oauth2.service_account import Credentials

# %% [markdown]
# ## Pipeline A

# %%
SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("Chatbot Ops Report").worksheet("Raw Data Robot Succes ratio")
data = sheet.get_all_values()

df = pd.DataFrame(data[1:], columns=data[0])
df.to_csv('../../raw_data/robot_success_ratio.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
#       2 SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
#       3           'https://www.googleapis.com/auth/drive']
# ----> 5 creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
#       6 client = gspread.authorize(creds)
#       8 sheet = client.open("Chatbot Ops Report").worksheet("Raw Data Robot Succes ratio")
#
# NameError: name 'Credentials' is not defined

# %%
df_clean = (
    df.copy()
    .rename(columns=lambda c: c.encode('ascii', 'ignore').decode('ascii').strip())
    .replace('', pd.NA)
    .dropna(subset=['Connected to robot'], how='all')
)

df_clean
# Out:
#      Connected to robot Number of exit queues Transfer amount to CS  \
# 0                   321                    25                   182
# 1                  1521                    80                   902
# 2                  2728                   100                  1570
# 3                  4424                   276                  2568
# 4                  6405                   540                  3378
# ...                 ...                   ...                   ...
# 1539              11690                     8                  5009
# 1540              11261                     0                  4858
# 1541              10611                     1                  4503
# 1542               9870                     0                  4069
# 1543              12806                     0                  5355
#
#      Total handle robot Robot handle ratio Robot actual completion ratio  \
# 0                   139             43.30%                        35.51%
# 1                   619             40.70%                        35.44%
# 2                  1158             42.45%                        38.78%
# 3                  1856             41.95%                        35.71%
# 4                  3027             47.26%                        38.83%
# ...                 ...                ...                           ...
# 1539               6681             57.15%                        57.08%
# 1540               6403             56.86%                        56.86%
# 1541               6108             57.56%                        57.55%
# 1542               5801             58.77%                        58.77%
# 1543               7451             58.18%                        58.18%
#
#      Robot Success ratio         Date
# 0                 31.00%  20-May-2022  <NA>  <NA>
# 1                 34.00%  21-May-2022  <NA>  <NA>
# 2                 37.00%  22-May-2022  <NA>  <NA>
# 3                 33.00%  23-May-2022  <NA>  <NA>
# 4                 36.00%  24-May-2022  <NA>  <NA>
# ...                  ...          ...   ...   ...
# 1539              57.08%   6-Aug-2026  <NA>  <NA>
# 1540              56.86%   7-Aug-2026  <NA>  <NA>
# 1541              57.55%   8-Aug-2026  <NA>  <NA>
# 1542              58.77%   9-Aug-2026  <NA>  <NA>
# 1543              58.18%  10-Aug-2026  <NA>  <NA>
#
# [1544 rows x 10 columns]

# %%
# Removing last row
df_clean = df_clean[:-1]

# %%
df_clean['Date'] = pd.to_datetime(df_clean['Date'], format='%d-%b-%Y', errors='coerce')

clean_list = ['Robot handle ratio',
              'Robot actual completion ratio', 
              'Robot Success ratio']

for col in clean_list:
    df_clean[col] = df_clean[col].str.replace('%','',regex=False).astype(float)

df_clean
# Out:
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_4440\3431615758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Date'] = pd.to_datetime(df_clean['Date'], format='%d-%b-%Y', errors='coerce')
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_4440\3431615758.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[col] = df_clean[col].str.replace('%','',regex=False).astype(float)
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_4440\3431615758.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[col] = df_clean[col].str.replace('%','',regex=False).astype(float)
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_4440\3431615758.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[col] = df_clean[col].str.replace('%','',regex=False).astype(float)
#      Connected to robot Number of exit queues Transfer amount to CS  \
# 0                   321                    25                   182
# 1                  1521                    80                   902
# 2                  2728                   100                  1570
# 3                  4424                   276                  2568
# 4                  6405                   540                  3378
# ...                 ...                   ...                   ...
# 1538              12169                     1                  5130
# 1539              11690                     8                  5009
# 1540              11261                     0                  4858
# 1541              10611                     1                  4503
# 1542               9870                     0                  4069
#
#      Total handle robot  Robot handle ratio  Robot actual completion ratio  \
# 0                   139               43.30                          35.51
# 1                   619               40.70                          35.44
# 2                  1158               42.45                          38.78
# 3                  1856               41.95                          35.71
# 4                  3027               47.26                          38.83
# ...                 ...                 ...                            ...
# 1538               7039               57.84                          57.84
# 1539               6681               57.15                          57.08
# 1540               6403               56.86                          56.86
# 1541               6108               57.56                          57.55
# 1542               5801               58.77                          58.77
#
#       Robot Success ratio       Date
# 0                   31.00 2022-05-20  <NA>  <NA>
# 1                   34.00 2022-05-21  <NA>  <NA>
# 2                   37.00 2022-05-22  <NA>  <NA>
# 3                   33.00 2022-05-23  <NA>  <NA>
# 4                   36.00 2022-05-24  <NA>  <NA>
# ...                   ...        ...   ...   ...
# 1538                57.84 2026-08-05  <NA>  <NA>
# 1539                57.08 2026-08-06  <NA>  <NA>
# 1540                56.86 2026-08-07  <NA>  <NA>
# 1541                57.55 2026-08-08  <NA>  <NA>
# 1542                58.77 2026-08-09  <NA>  <NA>
#
# [1543 rows x 10 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1543 entries, 0 to 1542
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Connected to robot             1543 non-null   object
#  1   Number of exit queues          1543 non-null   object
#  2   Transfer amount to CS          1543 non-null   object
#  3   Total handle robot             1543 non-null   object
#  4   Robot handle ratio             1543 non-null   float64
#  5   Robot actual completion ratio  1543 non-null   float64
#  6   Robot Success ratio            1543 non-null   float64
#  7   Date                           1543 non-null   datetime64[ns]
#  8                                  0 non-null      object
#  9                                  1 non-null      object
# dtypes: datetime64[ns](1), float64(3), object(6)
# memory usage: 120.7+ KB

# %% [markdown]
# ## Pipeline B

# %%
df_clean.to_csv('../../dataset_kula/success_ratio.csv')
