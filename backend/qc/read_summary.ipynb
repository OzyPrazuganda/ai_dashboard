# %%
import gspread
import pandas as pd
import matplotlib.pyplot as plt
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/Credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open('AI Summary Tagging').worksheet("AI Summary")
data = sheet.get_all_values()

df = pd.DataFrame(data[2:], columns=data[1])

# %%
analysis = df.drop(columns=['No'])
analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6012 entries, 0 to 6011
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Tanggal Pengerjaan           6012 non-null   object
#  1   Checker                      6012 non-null   object
#  2   ASI/AFI                      6012 non-null   object
#  3   Nama Agent                   6012 non-null   object
#  4   ID Ticket                    6012 non-null   object
#  5   Summary Avail                6012 non-null   object
#  6   Case Status                  6012 non-null   object
#  7   Waktu Chat                   6012 non-null   object
#  8   Sentimen Pengguna            6012 non-null   object
#  9   Revisi Sentimen              6012 non-null   object
#  10  Masalah Pelanggan            6012 non-null   object
#  11  Solusi                       6012 non-null   object
#  12  Perselisihan                 6012 non-null   object
#  13  Apakah Sudah Terselesaikan?  6012 non-null   object
#  14  Hasil Summary                6012 non-null   object
#  15  Alasan Tidak Suka            6012 non-null   object
#  16  REVISI                       6012 non-null   object
# dtypes: object(17)
# memory usage: 798.6+ KB

# %%
plt.figure(figsize=(10, 6))
