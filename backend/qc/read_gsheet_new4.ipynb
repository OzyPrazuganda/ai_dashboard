# %%
import streamlit as st
import pandas as pd
import numpy as np
import gspread
import plotly.express as px
import plotly.graph_objects as go

from datetime import timedelta
from google.oauth2.service_account import Credentials
from collections import defaultdict

# %%
# Read data from gsheet

SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']
creds = Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("[3] AI QC Inbound CRM Review 语音智能质检打标复审 ").worksheet("NEW 4")
data = sheet.get_all_values()

raw_headers = data[3]
rows = data[:4]
header_counter = defaultdict(int)
unique_header = []

for header in raw_headers:
    base = header if header.strip() != '' else 'Unnamed'
    header_counter[base] += 1

    if header_counter[base] == 1:
        unique_header.append(base)
    else:
        unique_header.append(f"{base}_{header_counter}[base]-1")

df = pd.DataFrame(data[2:], columns=unique_header)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162932 entries, 0 to 162931
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   No                                162932 non-null  object
#  1   Tanggal Pengerjaan                162932 non-null  object
#  2   Checker                           162932 non-null  object
#  3   ASI/AFI                           162932 non-null  object
#  4   Waktu Inbound                     162932 non-null  object
#  5   Nomor Inbound                     162932 non-null  object
#  6   Nama Agent                        162932 non-null  object
#  7   Call ID                           162932 non-null  object
#  8   Durasi Bicara                     162932 non-null  object
#  9   Detik                             162932 non-null  object
#  10  Total Tiket Riskan                162932 non-null  object
#  11  Apakah Riskan?                    162932 non-null  object
#  12  Tinjauan CS                       162932 non-null  object
#  13  Status                            162932 non-null  object
#  14  Sampling user side                162932 non-null  object
#  15  Hasil Pemeriksaan Kualitas (old)  162932 non-null  object
#  16  Hasil ASR                         162932 non-null  object
#  17  Hasil Pemeriksaan Kualitas        162932 non-null  object
#  18  Efektif                           162932 non-null  object
#  19  Kejelasan Suara                   162932 non-null  object
#  20  Suara Lain                        162932 non-null  object
#  21  Kelengkapan Rekaman               162932 non-null  object
#  22  Agent Sampling                    162932 non-null  object
# dtypes: object(23)
# memory usage: 28.6+ MB

# %%
# Data Cleaning
df_clean = df.copy()

# Hapus 2 baris awal
df_clean = df_clean.iloc[2:].reset_index(drop=True)

# Bersihkan nama kolom dan ganti yang kosong
df_clean.columns = [col.strip() if col.strip() else 'Catatan Tambahan' for col in df_clean.columns]

# Konversi kolom datetime jika ada
for col in ['Tanggal Pengerjaan', 'Waktu Inbound']:
    if col in df_clean.columns:
        df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')

# Konversi kolom numerik
if 'No' in df_clean.columns:
    df_clean['No'] = pd.to_numeric(df_clean['No'], errors='coerce')

# Bersihkan kolom teks
text_columns = df_clean.select_dtypes(include='object').columns
df_clean[text_columns] = df_clean[text_columns].apply(lambda s: s.astype(str).str.strip())
df_clean.replace('', 'No Data', inplace=True)

# Konversi kolom kategorikal jika ada
categorical_cols = [
    'Checker', 'ASI/AFI', 'Status',
    'Efektif', 'Kejelasan Suara', 'Suara Lain',
    'Kelengkapan Rekaman', 'Sampling user side',
    'Hasil ASR', 'Hasil Pemeriksaan Kualitas', 'Agent Sampling'
]
for col in categorical_cols:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].astype('category')

# Hapus kolom 'Status' jika ada
df_clean.drop(columns=['Status'], errors='ignore', inplace=True)

# Tampilkan info
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162930 entries, 0 to 162929
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   No                                162929 non-null  float64
#  1   Tanggal Pengerjaan                59796 non-null   datetime64[ns]
#  2   Checker                           162930 non-null  category
#  3   ASI/AFI                           162930 non-null  category
#  4   Waktu Inbound                     0 non-null       datetime64[ns]
#  5   Nomor Inbound                     162930 non-null  object
#  6   Nama Agent                        162930 non-null  object
#  7   Call ID                           162930 non-null  object
#  8   Durasi Bicara                     162930 non-null  object
#  9   Detik                             162930 non-null  object
#  10  Total Tiket Riskan                162930 non-null  object
#  11  Apakah Riskan?                    162930 non-null  object
#  12  Tinjauan CS                       162930 non-null  object
#  13  Sampling user side                162930 non-null  category
#  14  Hasil Pemeriksaan Kualitas (old)  162930 non-null  object
#  15  Hasil ASR                         162930 non-null  category
#  16  Hasil Pemeriksaan Kualitas        162930 non-null  category
#  17  Efektif                           162930 non-null  category
#  18  Kejelasan Suara                   162930 non-null  category
#  19  Suara Lain                        162930 non-null  category
#  20  Kelengkapan Rekaman               162930 non-null  category
#  21  Agent Sampling                    162930 non-null  category
# dtypes: category(10), datetime64[ns](2), float64(1), object(9)
# memory usage: 16.5+ MB

# %%
df_clean
# Out:
#               No Tanggal Pengerjaan  Checker  ASI/AFI Waktu Inbound  \
# 0            NaN                NaT  Checker  ASI/AFI           NaT
# 1            1.0         2025-10-03     Azer      ASI           NaT
# 2            2.0         2025-10-03     Azer      ASI           NaT
# 3            3.0         2025-10-03     Azer      ASI           NaT
# 4            4.0         2025-10-03     Azer      ASI           NaT
# ...          ...                ...      ...      ...           ...
# 162925  162925.0                NaT      Aul      AFI           NaT
# 162926  162926.0                NaT      Aul      AFI           NaT
# 162927  162927.0                NaT      Aul      AFI           NaT
# 162928  162928.0                NaT      Aul      AFI           NaT
# 162929  162929.0                NaT      Aul      AFI           NaT
#
#         Nomor Inbound              Nama Agent  \
# 0       Nomor Inbound              Nama Agent
# 1        0812****7814  TCHL_Anindyka Alfisyah
# 2        0812****7814  TCHL_Anindyka Alfisyah
# 3        0812****7814  TCHL_Anindyka Alfisyah
# 4        0812****7814  TCHL_Anindyka Alfisyah
# ...               ...                     ...
# 162925     0818**6780               Damayanti
# 162926     0818**6780               Damayanti
# 162927     0818**6780               Damayanti
# 162928     0818**6780               Damayanti
# 162929     0818**6780               Damayanti
#
#                                  Call ID  Durasi Bicara                Detik  \
# 0                                Call ID  Durasi Bicara                Detik
# 1       09a7b53c48c7419ab54ca4b412cb6257        0:26:27  2025-03-07 13:06:54
# 2       09a7b53c48c7419ab54ca4b412cb6257        0:26:27  2025-03-07 13:07:08
# 3       09a7b53c48c7419ab54ca4b412cb6257        0:26:27  2025-03-07 13:07:13
# 4       09a7b53c48c7419ab54ca4b412cb6257        0:26:27  2025-03-07 13:07:20
# ...                                  ...            ...                  ...
# 162925  081a9aba28064343b955313be487eadf        0:05:25  2025-09-22 11:41:28
# 162926  081a9aba28064343b955313be487eadf        0:05:25  2025-09-22 11:41:30
# 162927  081a9aba28064343b955313be487eadf        0:05:25  2025-09-22 11:41:32
# 162928  081a9aba28064343b955313be487eadf        0:05:25  2025-09-22 11:41:35
# 162929  081a9aba28064343b955313be487eadf        0:05:25  2025-09-22 11:41:36
#
#         ...  Tinjauan CS  Sampling user side  \
# 0       ...  Tinjauan CS  Sampling user side
# 1       ...      No Data                Done
# 2       ...      No Data                Done
# 3       ...      No Data                Done
# 4       ...      No Data                Done
# ...     ...          ...                 ...
# 162925  ...      No Data                Done
# 162926  ...      No Data                Done
# 162927  ...      No Data                Done
# 162928  ...      No Data                Done
# 162929  ...      No Data                Done
#
#         Hasil Pemeriksaan Kualitas (old)           Hasil ASR  \
# 0       Hasil Pemeriksaan Kualitas (old)           Hasil ASR
# 1                                No Data        Entri Akurat
# 2                                No Data        Entri Akurat
# 3                                No Data  Terdapat kesalahan
# 4                                No Data  Terdapat kesalahan
# ...                                  ...                 ...
# 162925                           No Data  Terdapat kesalahan
# 162926                           No Data        Entri Akurat
# 162927                           No Data  Terdapat kesalahan
# 162928                           No Data  Terdapat kesalahan
# 162929                           No Data  Terdapat kesalahan
#
#                  Hasil Pemeriksaan Kualitas              Efektif  \
# 0                Hasil Pemeriksaan Kualitas              Efektif
# 1                         Percakapan Normal  Miss Target/ Not HC
# 2                         Percakapan Normal  Miss Target/ Not HC
# 3                         Percakapan Normal  Miss Target/ Not HC
# 4                         Percakapan Normal  Miss Target/ Not HC
# ...                                     ...                  ...
# 162925  Percakapan normal & aturan  lainnya  Miss Target/ Not HC
# 162926                    Percakapan Normal  Miss Target/ Not HC
# 162927  Percakapan normal & aturan  lainnya  Miss Target/ Not HC
# 162928  Percakapan normal & aturan  lainnya  Miss Target/ Not HC
# 162929  Percakapan normal & aturan  lainnya  Miss Target/ Not HC
#
#                                Kejelasan Suara              Suara Lain  \
# 0                              Kejelasan Suara              Suara Lain
# 1       Sangat jelas, tidak bising sama sekali        0 Satu pembicara
# 2       Sangat jelas, tidak bising sama sekali        0 Satu pembicara
# 3                                  Cukup Jelas  1 Suara tumpang tindih
# 4                                  Cukup Jelas        0 Satu pembicara
# ...                                        ...                     ...
# 162925                        Konten Non Vokal        0 Satu pembicara
# 162926                        Konten Non Vokal        0 Satu pembicara
# 162927                        Konten Non Vokal        0 Satu pembicara
# 162928                        Konten Non Vokal        0 Satu pembicara
# 162929                        Konten Non Vokal        0 Satu pembicara
#
#         Kelengkapan Rekaman  Agent Sampling
# 0       Kelengkapan Rekaman  Agent Sampling
# 1                    0 Utuh         No Data
# 2                    0 Utuh         No Data
# 3              1 Tidak Utuh         No Data
# 4                    0 Utuh         No Data
# ...                     ...             ...
# 162925         1 Tidak Utuh         No Data
# 162926               0 Utuh         No Data
# 162927         1 Tidak Utuh         No Data
# 162928         1 Tidak Utuh         No Data
# 162929         1 Tidak Utuh         No Data
#
# [162930 rows x 22 columns]

# %%
df_clean.to_csv('../../dataset_qc/new_4_clean.csv')
