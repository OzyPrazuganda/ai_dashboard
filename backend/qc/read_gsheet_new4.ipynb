# %%
import streamlit as st
import pandas as pd
import numpy as np
import gspread
import plotly.express as px
import plotly.graph_objects as go

from datetime import timedelta
from google.oauth2.service_account import Credentials
from collections import defaultdict

# %%
# Read data from gsheet

SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']
creds = Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("[3] AI QC Inbound CRM Review 语音智能质检打标复审 ").worksheet("NEW 4")
data = sheet.get_all_values()

raw_headers = data[2]
rows = data[:3]
header_counter = defaultdict(int)
unique_header = []

for header in raw_headers:
    base = header if header.strip() != '' else 'Unnamed'
    header_counter[base] += 1

    if header_counter[base] == 1:
        unique_header.append(base)
    else:
        unique_header.append(f"{base}_{header_counter}[base]-1")

df = pd.DataFrame(data[1:], columns=unique_header)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146408 entries, 0 to 146407
# Data columns (total 23 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                          Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                          --------------   -----
#  0   No                                                                                                                                                                                                                                                                                                                                                                                              146408 non-null  object
#  1   Tanggal Pengerjaan                                                                                                                                                                                                                                                                                                                                                                              146408 non-null  object
#  2   Checker                                                                                                                                                                                                                                                                                                                                                                                         146408 non-null  object
#  3   ASI/AFI                                                                                                                                                                                                                                                                                                                                                                                         146408 non-null  object
#  4   Waktu Inbound                                                                                                                                                                                                                                                                                                                                                                                   146408 non-null  object
#  5   Nomor Inbound                                                                                                                                                                                                                                                                                                                                                                                   146408 non-null  object
#  6   Nama Agent                                                                                                                                                                                                                                                                                                                                                                                      146408 non-null  object
#  7   Call ID                                                                                                                                                                                                                                                                                                                                                                                         146408 non-null  object
#  8   Durasi Bicara                                                                                                                                                                                                                                                                                                                                                                                   146408 non-null  object
#  9   Detik                                                                                                                                                                                                                                                                                                                                                                                           146408 non-null  object
#  10  Total Tiket Riskan                                                                                                                                                                                                                                                                                                                                                                              146408 non-null  object
#  11  Apakah Riskan?                                                                                                                                                                                                                                                                                                                                                                                  146408 non-null  object
#  12  Tinjauan CS                                                                                                                                                                                                                                                                                                                                                                                     146408 non-null  object
#  13  Status                                                                                                                                                                                                                                                                                                                                                                                          146408 non-null  object
#  14  Sampling user side                                                                                                                                                                                                                                                                                                                                                                              146408 non-null  object
#  15  Hasil Pemeriksaan Kualitas                                                                                                                                                                                                                                                                                                                                                                      146408 non-null  object
#  16  Hasil ASR                                                                                                                                                                                                                                                                                                                                                                                       146408 non-null  object
#  17  Hasil Pemeriksaan Kualitas_defaultdict(<class 'int'>, {'No': 1, 'Tanggal Pengerjaan': 1, 'Checker': 1, 'ASI/AFI': 1, 'Waktu Inbound': 1, 'Nomor Inbound': 1, 'Nama Agent': 1, 'Call ID ': 1, 'Durasi Bicara': 1, 'Detik ': 1, 'Total Tiket Riskan': 1, 'Apakah Riskan?': 1, 'Tinjauan CS': 1, 'Status': 1, 'Sampling user side': 1, 'Hasil Pemeriksaan Kualitas': 2, 'Hasil ASR ': 1})[base]-1  146408 non-null  object
#  18  Efektif                                                                                                                                                                                                                                                                                                                                                                                         146408 non-null  object
#  19  Kejelasan Suara                                                                                                                                                                                                                                                                                                                                                                                 146408 non-null  object
#  20  Suara Lain                                                                                                                                                                                                                                                                                                                                                                                      146408 non-null  object
#  21  Kelengkapan Rekaman                                                                                                                                                                                                                                                                                                                                                                             146408 non-null  object
#  22  Agent Sampling                                                                                                                                                                                                                                                                                                                                                                                  146408 non-null  object
# dtypes: object(23)
# memory usage: 25.7+ MB

# %%
# Data Cleaning
df_clean = df.copy()

# Hapus 2 baris awal
df_clean = df_clean.iloc[2:].reset_index(drop=True)

# Bersihkan nama kolom dan ganti yang kosong
df_clean.columns = [col.strip() if col.strip() else 'Catatan Tambahan' for col in df_clean.columns]

# Konversi kolom datetime jika ada
for col in ['Tanggal Pengerjaan', 'Waktu Inbound', 'Tanggal Sampling']:
    if col in df_clean.columns:
        df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')

# Konversi kolom numerik
if 'No' in df_clean.columns:
    df_clean['No'] = pd.to_numeric(df_clean['No'], errors='coerce')

# Bersihkan kolom teks
text_columns = df_clean.select_dtypes(include='object').columns
df_clean[text_columns] = df_clean[text_columns].apply(lambda s: s.astype(str).str.strip())
df_clean.replace('', 'No Data', inplace=True)

# Konversi kolom kategorikal jika ada
categorical_cols = [
    'Checker', 'ASI/AFI', 'Status',
    'Efektif', 'Kejelasan Suara', 'Suara Lain',
    'Kelengkapan Rekaman', 'Sampling user side',
    'Hasil ASR', 'Hasil Pemeriksaan Kualitas', 'Agent Sampling'
]
for col in categorical_cols:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].astype('category')

# Hapus kolom 'Status' jika ada
df_clean.drop(columns=['Status'], errors='ignore', inplace=True)

# Tampilkan info
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146406 entries, 0 to 146405
# Data columns (total 22 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                          Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                          --------------   -----
#  0   No                                                                                                                                                                                                                                                                                                                                                                                              146406 non-null  int64
#  1   Tanggal Pengerjaan                                                                                                                                                                                                                                                                                                                                                                              146395 non-null  datetime64[ns]
#  2   Checker                                                                                                                                                                                                                                                                                                                                                                                         146406 non-null  category
#  3   ASI/AFI                                                                                                                                                                                                                                                                                                                                                                                         146406 non-null  category
#  4   Waktu Inbound                                                                                                                                                                                                                                                                                                                                                                                   146395 non-null  datetime64[ns]
#  5   Nomor Inbound                                                                                                                                                                                                                                                                                                                                                                                   146406 non-null  object
#  6   Nama Agent                                                                                                                                                                                                                                                                                                                                                                                      146406 non-null  object
#  7   Call ID                                                                                                                                                                                                                                                                                                                                                                                         146406 non-null  object
#  8   Durasi Bicara                                                                                                                                                                                                                                                                                                                                                                                   146406 non-null  object
#  9   Detik                                                                                                                                                                                                                                                                                                                                                                                           146406 non-null  object
#  10  Total Tiket Riskan                                                                                                                                                                                                                                                                                                                                                                              146406 non-null  object
#  11  Apakah Riskan?                                                                                                                                                                                                                                                                                                                                                                                  146406 non-null  object
#  12  Tinjauan CS                                                                                                                                                                                                                                                                                                                                                                                     146406 non-null  object
#  13  Sampling user side                                                                                                                                                                                                                                                                                                                                                                              146406 non-null  category
#  14  Hasil Pemeriksaan Kualitas                                                                                                                                                                                                                                                                                                                                                                      146406 non-null  category
#  15  Hasil ASR                                                                                                                                                                                                                                                                                                                                                                                       146406 non-null  category
#  16  Hasil Pemeriksaan Kualitas_defaultdict(<class 'int'>, {'No': 1, 'Tanggal Pengerjaan': 1, 'Checker': 1, 'ASI/AFI': 1, 'Waktu Inbound': 1, 'Nomor Inbound': 1, 'Nama Agent': 1, 'Call ID ': 1, 'Durasi Bicara': 1, 'Detik ': 1, 'Total Tiket Riskan': 1, 'Apakah Riskan?': 1, 'Tinjauan CS': 1, 'Status': 1, 'Sampling user side': 1, 'Hasil Pemeriksaan Kualitas': 2, 'Hasil ASR ': 1})[base]-1  146406 non-null  object
#  17  Efektif                                                                                                                                                                                                                                                                                                                                                                                         146406 non-null  category
#  18  Kejelasan Suara                                                                                                                                                                                                                                                                                                                                                                                 146406 non-null  category
#  19  Suara Lain                                                                                                                                                                                                                                                                                                                                                                                      146406 non-null  category
#  20  Kelengkapan Rekaman                                                                                                                                                                                                                                                                                                                                                                             146406 non-null  category
#  21  Agent Sampling                                                                                                                                                                                                                                                                                                                                                                                  146406 non-null  category
# dtypes: category(10), datetime64[ns](2), int64(1), object(9)
# memory usage: 14.8+ MB

# %%
df_clean
# Out:
#             No Tanggal Pengerjaan  Checker  ASI/AFI       Waktu Inbound  \
# 0            1         2025-03-10     Azer      ASI 2025-03-07 13:06:19
# 1            2         2025-03-10     Azer      ASI 2025-03-07 13:06:19
# 2            3         2025-03-10     Azer      ASI 2025-03-07 13:06:19
# 3            4         2025-03-10     Azer      ASI 2025-03-07 13:06:19
# 4            5         2025-03-10     Azer      ASI 2025-03-07 13:06:19
# ...        ...                ...      ...      ...                 ...
# 146401  146402                NaT  No Data  No Data                 NaT
# 146402  146403                NaT  No Data  No Data                 NaT
# 146403  146404                NaT  No Data  No Data                 NaT
# 146404  146405                NaT  No Data  No Data                 NaT
# 146405  146406                NaT  No Data  No Data                 NaT
#
#        Nomor Inbound              Nama Agent  \
# 0       0812****7814  TCHL_Anindyka Alfisyah
# 1       0812****7814  TCHL_Anindyka Alfisyah
# 2       0812****7814  TCHL_Anindyka Alfisyah
# 3       0812****7814  TCHL_Anindyka Alfisyah
# 4       0812****7814  TCHL_Anindyka Alfisyah
# ...              ...                     ...
# 146401       No Data                 No Data
# 146402       No Data                 No Data
# 146403       No Data                 No Data
# 146404       No Data                 No Data
# 146405       No Data                 No Data
#
#                                  Call ID Durasi Bicara                Detik  \
# 0       09a7b53c48c7419ab54ca4b412cb6257       0:26:27  2025-03-07 13:06:54
# 1       09a7b53c48c7419ab54ca4b412cb6257       0:26:27  2025-03-07 13:07:08
# 2       09a7b53c48c7419ab54ca4b412cb6257       0:26:27  2025-03-07 13:07:13
# 3       09a7b53c48c7419ab54ca4b412cb6257       0:26:27  2025-03-07 13:07:20
# 4       09a7b53c48c7419ab54ca4b412cb6257       0:26:27  2025-03-07 13:07:26
# ...                                  ...           ...                  ...
# 146401                           No Data       No Data              No Data
# 146402                           No Data       No Data              No Data
# 146403                           No Data       No Data              No Data
# 146404                           No Data       No Data              No Data
# 146405                           No Data       No Data              No Data
#
#         ... Tinjauan CS Sampling user side Hasil Pemeriksaan Kualitas  \
# 0       ...     No Data               Done                    No Data
# 1       ...     No Data               Done                    No Data
# 2       ...     No Data               Done                    No Data
# 3       ...     No Data               Done                    No Data
# 4       ...     No Data               Done                    No Data
# ...     ...         ...                ...                        ...
# 146401  ...     No Data            No Data                    No Data
# 146402  ...     No Data            No Data                    No Data
# 146403  ...     No Data            No Data                    No Data
# 146404  ...     No Data            No Data                    No Data
# 146405  ...     No Data            No Data                    No Data
#
#                  Hasil ASR  \
# 0             Entri Akurat
# 1             Entri Akurat
# 2       Terdapat kesalahan
# 3       Terdapat kesalahan
# 4       Terdapat kesalahan
# ...                    ...
# 146401             No Data
# 146402             No Data
# 146403             No Data
# 146404             No Data
# 146405             No Data
#
#        Hasil Pemeriksaan Kualitas_defaultdict(<class 'int'>, {'No': 1, 'Tanggal Pengerjaan': 1, 'Checker': 1, 'ASI/AFI': 1, 'Waktu Inbound': 1, 'Nomor Inbound': 1, 'Nama Agent': 1, 'Call ID ': 1, 'Durasi Bicara': 1, 'Detik ': 1, 'Total Tiket Riskan': 1, 'Apakah Riskan?': 1, 'Tinjauan CS': 1, 'Status': 1, 'Sampling user side': 1, 'Hasil Pemeriksaan Kualitas': 2, 'Hasil ASR ': 1})[base]-1  \
# 0                                       Percakapan Normal
# 1                                       Percakapan Normal
# 2                                       Percakapan Normal
# 3                                       Percakapan Normal
# 4                                       Percakapan Normal
# ...                                                   ...
# 146401                                            No Data
# 146402                                            No Data
# 146403                                            No Data
# 146404                                            No Data
# 146405                                            No Data
#
#                     Efektif                         Kejelasan Suara  \
# 0       Miss Target/ Not HC  Sangat jelas, tidak bising sama sekali
# 1       Miss Target/ Not HC  Sangat jelas, tidak bising sama sekali
# 2       Miss Target/ Not HC                             Cukup Jelas
# 3       Miss Target/ Not HC                             Cukup Jelas
# 4       Miss Target/ Not HC                             Cukup Jelas
# ...                     ...                                     ...
# 146401              No Data                                 No Data
# 146402              No Data                                 No Data
# 146403              No Data                                 No Data
# 146404              No Data                                 No Data
# 146405              No Data                                 No Data
#
#                     Suara Lain Kelengkapan Rekaman Agent Sampling
# 0             0 Satu pembicara              0 Utuh        No Data
# 1             0 Satu pembicara              0 Utuh        No Data
# 2       1 Suara tumpang tindih        1 Tidak Utuh        No Data
# 3             0 Satu pembicara              0 Utuh        No Data
# 4       1 Suara tumpang tindih              0 Utuh        No Data
# ...                        ...                 ...            ...
# 146401                 No Data             No Data        No Data
# 146402                 No Data             No Data        No Data
# 146403                 No Data             No Data        No Data
# 146404                 No Data             No Data        No Data
# 146405                 No Data             No Data        No Data
#
# [146406 rows x 22 columns]

# %%
df_clean.to_csv('../../dataset_qc/new_4_clean.csv')
