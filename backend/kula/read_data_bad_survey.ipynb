# %%
import gspread
import pandas as pd
from google.oauth2.service_account import Credentials

# %% [markdown]
# ## Pipeline A

# %%
SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("QC Chatbot ").worksheet("Sampling Bad Survey")
data = sheet.get_all_values()

df = pd.DataFrame(data[1:], columns=data[0])

# %%
df
# Out:
#       Checking Date Conversation Start Time    Week    Month          QC Name  \
# 0         1/31/2023               1/30/2023  Week 1  January  Nurhamni Septia
# 1         1/31/2023               1/30/2023  Week 1  January  Nurhamni Septia
# 2         1/31/2023               1/30/2023  Week 1  January  Nurhamni Septia
# 3         1/31/2023               1/30/2023  Week 1  January  Nurhamni Septia
# 4         1/31/2023               1/30/2023  Week 1  January  Nurhamni Septia
# ...             ...                     ...     ...      ...              ...
# 17394     8/20/2025               8/19/2025  Week 4   August
# 17395     8/20/2025               8/19/2025  Week 4   August
# 17396     8/20/2025               8/19/2025  Week 4   August
# 17397     8/20/2025               8/19/2025  Week 4   August
# 17398     8/20/2025               8/19/2025  Week 4   August
#
#            Business Type         UID                      ID Chat  \
# 0      No Differentiated  2010758137  2-2010758137-3-1_1675043140
# 1                    ASI  2011367987  2-2011367987-3-1_1675050791
# 2                    AFI  2016182809  2-2016182809-3-1_1675069380
# 3      No Differentiated  2017149569  2-2017149569-3-1_1675051331
# 4                    ASI  2018885687  2-2018885687-3-1_1675013279
# ...                  ...         ...                          ...
# 17394                     2049330886  2-2049330886-3-1_1755621871
# 17395                     2020796983  2-2020796983-3-1_1755586207
# 17396                     2038428538  2-2038428538-3-1_1755586105
# 17397                        2257413     2-2257413-3-1_1755613234
# 17398                     2046029220  2-2046029220-3-1_1755576614
#
#       Main Category                                   QC Result  \
# 0            SYSTEM                        Robots don't show up
# 1       CHATBOT OPS                     Add Question Simulation
# 2          Customer  Information Not Meet Customer Expectations
# 3          Customer                      Chat Customer No Clear
# 4          Customer  Information Not Meet Customer Expectations
# ...             ...                                         ...
# 17394
# 17395
# 17396
# 17397
# 17398
#
#                                             Sub Category Suggestion Rate  \
# 0                         Others could not be identified          Medium
# 1                  Online Merchant - Shipping Complaints          Urgent
# 2      Have a loan on another platform, cannot make t...             N/A
# 3                                              Chit-chat             N/A
# 4                    Online Merchant - No receipt number             N/A
# ...                                                  ...             ...
# 17394
# 17395
# 17396
# 17397
# 17398
#
#              Type                           Category Code_lama Code  \
# 0      Bad Survey                        No Category    209901
# 1      Bad Survey                    Merchant Online    131901
# 2      Bad Survey  Submission of Limit/Credit Points    050301
# 3      Bad Survey                        No Category         -    -
# 4      Bad Survey                    Merchant Online    131201
# ...           ...                                ...       ...  ...
# 17394
# 17395
# 17396
# 17397
# 17398
#
#                                                  Remarks Rating
# 0      Robot tidak mengirimkan jawaban seharusnya bis...      1
# 1      kalau emang belum di kirim hari ini saya akan ...      1
# 2      Customer telah memilih pertanyaan dan jawabann...      1
# 3      Customer tidak chat apapun hanya menampilkan t...      1
# 4      Pertanyaan dan jawaban sudah sesuai FAQ, namun...      1
# ...                                                  ...    ...
# 17394                                                         1
# 17395                                                         1
# 17396                                                         1
# 17397                                                         1
# 17398                                                         1
#
# [17399 rows x 18 columns]

# %%
df_clean = df.copy()

df_clean['Checking Date'] = pd.to_datetime(df_clean['Checking Date'], format="%m/%d/%Y", errors='coerce')
df_clean['Conversation Start Time'] = pd.to_datetime(df_clean['Conversation Start Time'], format="%m/%d/%Y", errors='coerce')

df_clean = df_clean.drop('Code_lama', axis=1)
df_clean['Code'] = df_clean['Code'].fillna('').replace('-', '')

df_clean['Rating'] = pd.to_numeric(df_clean['Rating'], errors='coerce')

df_clean = df_clean.drop_duplicates()

df_clean = df_clean.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

df_clean
# Out:
#       Checking Date Conversation Start Time    Week    Month          QC Name  \
# 0        2023-01-31              2023-01-30  Week 1  January  Nurhamni Septia
# 1        2023-01-31              2023-01-30  Week 1  January  Nurhamni Septia
# 2        2023-01-31              2023-01-30  Week 1  January  Nurhamni Septia
# 3        2023-01-31              2023-01-30  Week 1  January  Nurhamni Septia
# 4        2023-01-31              2023-01-30  Week 1  January  Nurhamni Septia
# ...             ...                     ...     ...      ...              ...
# 17394    2025-08-20              2025-08-19  Week 4   August
# 17395    2025-08-20              2025-08-19  Week 4   August
# 17396    2025-08-20              2025-08-19  Week 4   August
# 17397    2025-08-20              2025-08-19  Week 4   August
# 17398    2025-08-20              2025-08-19  Week 4   August
#
#            Business Type         UID                      ID Chat  \
# 0      No Differentiated  2010758137  2-2010758137-3-1_1675043140
# 1                    ASI  2011367987  2-2011367987-3-1_1675050791
# 2                    AFI  2016182809  2-2016182809-3-1_1675069380
# 3      No Differentiated  2017149569  2-2017149569-3-1_1675051331
# 4                    ASI  2018885687  2-2018885687-3-1_1675013279
# ...                  ...         ...                          ...
# 17394                     2049330886  2-2049330886-3-1_1755621871
# 17395                     2020796983  2-2020796983-3-1_1755586207
# 17396                     2038428538  2-2038428538-3-1_1755586105
# 17397                        2257413     2-2257413-3-1_1755613234
# 17398                     2046029220  2-2046029220-3-1_1755576614
#
#       Main Category                                   QC Result  \
# 0            SYSTEM                        Robots don't show up
# 1       CHATBOT OPS                     Add Question Simulation
# 2          Customer  Information Not Meet Customer Expectations
# 3          Customer                      Chat Customer No Clear
# 4          Customer  Information Not Meet Customer Expectations
# ...             ...                                         ...
# 17394
# 17395
# 17396
# 17397
# 17398
#
#                                             Sub Category Suggestion Rate  \
# 0                         Others could not be identified          Medium
# 1                  Online Merchant - Shipping Complaints          Urgent
# 2      Have a loan on another platform, cannot make t...             N/A
# 3                                              Chit-chat             N/A
# 4                    Online Merchant - No receipt number             N/A
# ...                                                  ...             ...
# 17394
# 17395
# 17396
# 17397
# 17398
#
#              Type                           Category Code  \
# 0      Bad Survey                        No Category
# 1      Bad Survey                    Merchant Online
# 2      Bad Survey  Submission of Limit/Credit Points
# 3      Bad Survey                        No Category
# 4      Bad Survey                    Merchant Online
# ...           ...                                ...  ...
# 17394
# 17395
# 17396
# 17397
# 17398
#
#                                                  Remarks  Rating
# 0      Robot tidak mengirimkan jawaban seharusnya bis...     1.0
# 1      kalau emang belum di kirim hari ini saya akan ...     1.0
# 2      Customer telah memilih pertanyaan dan jawabann...     1.0
# 3      Customer tidak chat apapun hanya menampilkan t...     1.0
# 4      Pertanyaan dan jawaban sudah sesuai FAQ, namun...     1.0
# ...                                                  ...     ...
# 17394                                                        1.0
# 17395                                                        1.0
# 17396                                                        1.0
# 17397                                                        1.0
# 17398                                                        1.0
#
# [17396 rows x 17 columns]

# %%
df_clean.to_csv('../../dataset_kula/bad_survey.csv')
