# %%
import gspread
import pandas as pd
from rapidfuzz import fuzz, process
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("QC Chatbot ").worksheet("Sampling Bad Survey")
data = sheet.get_all_values()

df = pd.DataFrame(data[1:], columns=data[0])

# %%
query = "Kenapa saya tidak bisa top up e wallet di aplikasi Akulaku?"

# Hitung skor kemiripan terhadap seluruh kolom 'Remarks'
df['similarity'] = df['Remarks'].apply(lambda x: fuzz.token_sort_ratio(query, str(x)))

# Ambil yang paling mirip (misal ambil yang di atas 80%)
df_similar = df[df['similarity'] > 50].sort_values(by='similarity', ascending=False)

print(df_similar[['Remarks', 'similarity']].head())
# Out:
#                                                 Remarks  similarity
# 398   Kenapa top up DANA tidak bisa pakai Paylater A...   71.428571
# 194   Kenapa tidak bisa transaksi di TikTok pakai Ak...   68.468468
# 5626  Kenapa di aplikasi Shopee tidak ada metode pem...   64.462810
# 6866  Kenapa saya tidak bisa menghubungkan akun BPJS...   62.903226
# 2210  Kenapa mau transaksi di Bukalapak tidak bisa p...   62.711864
