# %%
import gspread
import pandas as pd
from datetime import date
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("QC Chatbot [dislike]").worksheet("Sampling [dislike]")
data = sheet.get_all_values()

df = pd.DataFrame(data[1:], columns=data[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72770 entries, 0 to 72769
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Checking Date                   72770 non-null  object
#  1   Score_date                      72770 non-null  object
#  2   Week                            72770 non-null  object
#  3   Month                           72770 non-null  object
#  4   QC Name                         72770 non-null  object
#  5   Business Type                   72770 non-null  object
#  6   Code                            72770 non-null  object
#  7   unsolved_num                    72770 non-null  object
#  8    FAQ Check                      72770 non-null  object
#  9   FAQ Status                      72770 non-null  object
#  10  Main Category                   72770 non-null  object
#  11  Checking Result
# (Sub Category)  72770 non-null  object
#  12  Background detail- ID           72770 non-null  object
#  13  Team/Category                   72770 non-null  object
#  14  Type System Checking            72770 non-null  object
#  15  Result Analyze                  72770 non-null  object
#  16  Review FAQ                      72770 non-null  object
#  17  Review FAQ
# [Status]             72770 non-null  object
#  18  Online in Robot's               72770 non-null  object
# dtypes: object(19)
# memory usage: 10.5+ MB
