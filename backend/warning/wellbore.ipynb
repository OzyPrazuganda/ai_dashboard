# %%
import gspread
import pandas as pd
from pandasql import sqldf
from google.oauth2.service_account import Credentials

# %%
SERVICE_ACCOUNT_FILE = '../../key/credentials.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets',
          'https://www.googleapis.com/auth/drive']

creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

sheet = client.open("KULA HC CASE Review 07/27").worksheet("Dashboard")
data = sheet.get_all_values()

df = pd.DataFrame(data[2152:], columns=data[0])

# %%
data_1 = pd.read_csv('../../dataset_wellbore/akulaku_superset_presto_hanmm_ozy.prazuganda_1754632323_8_8.csv', low_memory=False)

# %%
result = pd.merge(data_1, df, left_on='UID', right_on='uid', how='right')
result = result.reset_index()

result = result.groupby('uid', as_index=False).head(1)

# %%
result
# Out:
#     index  company Aplication         UID  \
# 0       0      AFI        AFI  2021855263
# 2       2  Akulaku        ASI  2032001750
# 4       4  Akulaku        ASI  2035497616
# 6       6      AFI        AFI  2012640246
# 7       7      AFI        AFI     8677737
# 9       9  Akulaku        ASI  2047030113
# 11     11  Akulaku        ASI    91073968
# 15     15      AFI        AFI  2040312130
# 18     18  Akulaku        ASI  2027418040
# 20     20  Akulaku        ASI   124623765
#
#                                              UserName  \
# 0   AL$$_1_WVWoOQ/2wHPz/3MeSwfJXfs9OeKhQKBj//suPEs...
# 2   AL$$_1_Ao5twBo3Ba5YlnUd1/I5K8Fm2uchHDIJn2+b1Vp...
# 4   AL$$_1_P/8smzi+NU3c3aVDGY0sBrSolQeOMNCWISTw8hL...
# 6   AL$$_1_NrgFOsFMNhidRI0oL1h+ro5PvduxhAVEgvV7zEn...
# 7   AL$$_1_FY3V39tbfhDIDrHSOg0aBgdS2k3igClQF7yK49o...
# 9   AL$$_1_d9d1FLALW8nE0w1s5sUEvrFU1lpde5tVVLMAi/+...
# 11  AL$$_1_TpWrCc5I/ptDd9p666gCxscLo5lelPJpJHiGK79...
# 15  AL$$_1_jYmcIPTTJP6Johmz9g6+ZIlbZD4rNuoKDpSKeML...
# ...

# %%
result['Aplication'].to_list()
# Out:
# ['AFI', 'ASI', 'ASI', 'AFI', 'AFI', 'ASI', 'ASI', 'AFI', 'ASI', 'ASI']
