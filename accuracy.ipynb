# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1753329431_21.csv')
df_22 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1753341756_22.csv')
df_28 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1753775670_28.csv')
df_8_5 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1754385922_8_5.csv')
df_8_11 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1755226692_8_11_(2).csv')
df_8_12 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1755227592_8_12.csv')
df_8_18 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1755584976_8_18.csv')
# Out:
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_20784\3956049195.py:1: DtypeWarning: Columns (23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1753329431_21.csv')
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_20784\3956049195.py:3: DtypeWarning: Columns (23,24,25,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_28 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1753775670_28.csv')
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_20784\3956049195.py:4: DtypeWarning: Columns (23,24,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_8_5 = pd.read_csv('dataset_accuracy/akulaku_superset_presto_hanmm_ozy.prazuganda_1754385922_8_5.csv')

# %%
def calculate_accuracy(df):
    date = df['day'].unique()
    df_filtered = df[df.iloc[:, 21] == "是"].iloc[:, [21, 34]]
    accuracy = (df_filtered.iloc[:, 1] == "是").sum() / (df_filtered.iloc[:, 0] == "是").sum() * 100
    return accuracy, date

dataframes = [df, df_22, df_28, df_8_5, df_8_11, df_8_12, df_8_18]

for i, data in enumerate(dataframes, start=1):
    ratio, date = calculate_accuracy(data)
    print(f"{ratio:.2f} % Accuracy per {date}")
# Out:
# 95.99 % Accuracy per ['2025-07-21']
# 96.10 % Accuracy per ['2025-07-22']
# 97.96 % Accuracy per ['2025-07-28']
# 91.04 % Accuracy per ['2025-08-04']
# nan % Accuracy per ['2025-08-11']
# nan % Accuracy per ['2025-08-12']
# nan % Accuracy per ['2025-08-18']
# C:\Users\ozy.prazuganda\AppData\Local\Temp\ipykernel_20784\3622828442.py:4: RuntimeWarning: invalid value encountered in scalar divide
#   accuracy = (df_filtered.iloc[:, 1] == "是").sum() / (df_filtered.iloc[:, 0] == "是").sum() * 100

# %%
df_8_11[(df_8_11.iloc[:, 3] == "cfc0acbf0e384f2bb394355688ef5f45") & (df_8_11.iloc[:, 21] == "是")]
# Out:
# Empty DataFrame
# Columns: [day, ticket_id, application_name, call_id, processor_name, processor_account, call_start_time, call_end_time, call_way, answer_duration, customer_uid, customer_name, customer_phone, audio_begin_duration, audio_end_duration, audio_duration, part_type, text, call_audio_idresult, audit_result, audio_hit_flag, manual_hit_flag, manual_audit_asr, manual_audit_result, other_rule_desc, audit_time, audit_total_times, audit_asr_correct_count, audit_asr_correct_times, audit_asr_false_count, audit_asr_false_times, create_by, asr_text, correct_text, 质检是否正确, 质检是否有效, 声音清晰度, 其他声音, 完整度, create_time]
# Index: []
#
# [0 rows x 40 columns]
